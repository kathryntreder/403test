# %%
# Changing the language of a Kernel to R allows us to run R. Probably need to change R projects to initiate

# %%
data <- c(1,1,2,3,5,8)

# %%
print(data)
# Out:
# [1] 1 1 2 3 5 8

# %%
barplot(data, main = "Sample Bar Plot", xlab = "Count")
# Out:
# Plot with title “Sample Bar Plot”
